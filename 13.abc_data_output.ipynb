# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
abc=pd.read_csv("C:/python_test_cases/13.abc (1).csv")
abc
# Out:
# C:\Users\Sandeep\AppData\Local\Temp\ipykernel_8596\144096930.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   abc=pd.read_csv("C:/python_test_cases/13.abc (1).csv")
#                                              Registrar  \
# 0                                       Allahabad Bank
# 1                                       Allahabad Bank
# 2                                       Allahabad Bank
# 3                                       Allahabad Bank
# 4                                       Allahabad Bank
# ...                                                ...
# 440813  Women and Child Development Govt. of Jharkhand
# 440814  Women and Child Development Govt. of Jharkhand
# 440815  Women and Child Development Govt. of Jharkhand
# 440816  Women and Child Development Govt. of Jharkhand
# 440817  Women and Child Development Govt. of Jharkhand
#
#                            Enrolment Agency          State   District  \
# ...

# %%
total_no_of_cardsApproved_by_states=abc.groupby('State')['Aadhaar generated'].sum()
total_no_of_cardsApproved_by_states
# Out:
# State
# Andaman and Nicobar Islands         5
# Andhra Pradesh                   5798
# Arunachal Pradesh                 913
# Assam                            3213
# Bihar                          162607
# Chandigarh                        259
# Chhattisgarh                     6604
# Dadra and Nagar Haveli            140
# Daman and Diu                     105
# Delhi                            8426
# Goa                              1167
# Gujarat                         34844
# Haryana                          6804
# Himachal Pradesh                 1547
# Jammu and Kashmir                1234
# Jharkhand                        9868
# Karnataka                       19764
# Kerala                          15143
# Lakshadweep                         4
# Madhya Pradesh                  53276
# Maharashtra                     26085
# Manipur                          1323
# Meghalaya                         277
# Mizoram                          6279
# ...

# %%
total_no_of_EnrolmentRejected_by_states=abc.groupby('State')['Enrolment Rejected'].sum()
total_no_of_EnrolmentRejected_by_states
# Out:
# State
# Andaman and Nicobar Islands       2
# Andhra Pradesh                  373
# Arunachal Pradesh                79
# Assam                            28
# Bihar                          7209
# Chandigarh                        9
# Chhattisgarh                    380
# Dadra and Nagar Haveli            3
# Daman and Diu                     2
# Delhi                           591
# Goa                             127
# Gujarat                        2500
# Haryana                         532
# Himachal Pradesh                123
# Jammu and Kashmir               204
# Jharkhand                       477
# Karnataka                      1445
# Kerala                          538
# Lakshadweep                       1
# Madhya Pradesh                 3509
# Maharashtra                    1818
# Manipur                         190
# Meghalaya                         2
# Mizoram                         185
# Nagaland                         43
# Odisha                         1596
# ...

# %%
total_no_of_cardsApproved_by_District=abc.groupby('District')['Aadhaar generated'].sum()
total_no_of_cardsApproved_by_District
# Out:
# District
# Adilabad         265
# Agra            2283
# Ahmadnagar       476
# Ahmedabad       4212
# Aizawl          1095
#                 ...
# Wokha             32
# Yadgir           325
# Yamuna Nagar     197
# Yavatmal         712
# Zunheboto          8
# Name: Aadhaar generated, Length: 664, dtype: int64

# %%
total_no_of_EnrolmentRejected_by_district=abc.groupby('District')['Enrolment Rejected'].sum()
total_no_of_EnrolmentRejected_by_district
# Out:
# District
# Adilabad          7
# Agra            137
# Ahmadnagar       45
# Ahmedabad       278
# Aizawl          111
#                ...
# Wokha             2
# Yadgir           28
# Yamuna Nagar     11
# Yavatmal         78
# Zunheboto         0
# Name: Enrolment Rejected, Length: 664, dtype: int64

# %%
gender_count=abc['Gender'].value_counts()
gender_count
# Out:
# M    292798
# F    148013
# T         7
# Name: Gender, dtype: int64

# %%
# Count records based on age categories
age_less_than_25 = abc[abc['Age'] < 25]
age_between_25_and_35 = abc[(abc['Age'] >= 25) & (abc['Age'] <= 35)]
age_greater_than_45 = abc[abc['Age'] > 45]

# Get the counts
count_age_less_than_25 = len(age_less_than_25)
count_age_between_25_and_35 = len(age_between_25_and_35)
count_age_greater_than_45 = len(age_greater_than_45)

# Print the counts
print(f"Count of records with age < 25: {count_age_less_than_25}")
print(f"Count of records with age between 25 and 35: {count_age_between_25_and_35}")
print(f"Count of records with age > 45: {count_age_greater_than_45}")
# Out:
# Count of records with age < 25: 296836
# Count of records with age between 25 and 35: 62512
# Count of records with age > 45: 50610
